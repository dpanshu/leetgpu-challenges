# %% [markdown]
# # 36_radix_sort
#
# Audience: junior researcher
#
# - Challenge path: `challenges/hard/36_radix_sort`
# - Source spec: [challenges/hard/36_radix_sort/challenge.html](../challenge.html)
# - Source implementation: [challenges/hard/36_radix_sort/challenge.py](../challenge.py)

# %% [markdown]
# ## Problem Statement
#
# The original challenge HTML is embedded below so the notebook stays close to the repo source.
#
# <p>
#     Implement a radix sort algorithm that sorts an array of 32-bit unsigned integers on a GPU.
#     The program should take an input array of unsigned integers and sort them in ascending order using the radix sort algorithm.
#     The <code>input</code> parameter contains the unsorted array, and the sorted result should be stored in the <code>output</code> array.
#   </p>
#
#   <h2>Implementation Requirements</h2>
#   <ul>
#     <li>External libraries are not permitted</li>
#     <li>The <code>solve</code> function signature must remain unchanged</li>
#     <li>The final sorted result must be stored in the <code>output</code> array</li>
#     <li>Use radix sort algorithm (not other sorting algorithms)</li>
#     <li>Sort in ascending order</li>
#   </ul>
#
#   <h2>Example 1:</h2>
#   <pre>
#   Input:  [170, 45, 75, 90, 2, 802, 24, 66]
#   Output: [2, 24, 45, 66, 75, 90, 170, 802]
#   </pre>
#
#   <h2>Example 2:</h2>
#   <pre>
#   Input:  [1, 4, 1, 3, 555, 1000, 2]
#   Output: [1, 1, 2, 3, 4, 555, 1000]
#   </pre>
#
#   <h2>Constraints</h2>
#   <ul>
#     <li><code>1 ≤ N ≤ 100,000,000</code></li>
#     <li><code>0 ≤ input[i] ≤ 4,294,967,295</code> (32-bit unsigned integers)</li>
#
#   <li>Performance is measured with <code>N</code> = 50,000,000</li>
# </ul>

# %% [markdown]
# ## Framework Coverage
#
# This notebook collects the currently available solution artifacts for PyTorch, JAX, Triton, and MLX.

# %% [markdown]
# ## Pytorch
#
# Source: `challenges/hard/36_radix_sort/solution/solution.pytorch.py`

# %%
import torch


def solve(input: torch.Tensor, output: torch.Tensor, N: int):
    output.copy_(torch.sort(input.to(torch.int64))[0].to(torch.uint32))

# %% [markdown]
# ## Jax
#
# Source: `challenges/hard/36_radix_sort/solution/solution.jax.py`

# %%
from __future__ import annotations

try:
    import jax
    import jax.numpy as jnp
except Exception:  # pragma: no cover - optional dependency
    jax = None
    jnp = None

import torch


def _solve_impl(input, N: int):
    if jax is None:
        return torch.sort(input.to(torch.int64))[0].to(torch.uint32)
    return jnp.sort(input.astype(jnp.uint32))


if jax is None:

    def solve(input, N: int):
        return _solve_impl(input, N)

else:
    solve = jax.jit(_solve_impl)

# %% [markdown]
# ## Triton
#
# Source: `challenges/hard/36_radix_sort/solution/solution.triton.py`

# %%
import torch

try:
    import triton  # noqa: F401
    import triton.language as tl  # noqa: F401
except Exception:  # pragma: no cover - optional dependency
    triton = None
    tl = None


def solve(input: torch.Tensor, output: torch.Tensor, N: int):
    output.copy_(torch.sort(input.to(torch.int64))[0].to(torch.uint32))

# %% [markdown]
# ## Mlx
#
# No solution file is present yet.

# %% [markdown]
# ## Verification Notes
#
# Use `python scripts/verify_matrix_solutions.py` for the local matrix-operation verifier.
# GPU-only Triton validation still depends on a remote NVIDIA environment.
