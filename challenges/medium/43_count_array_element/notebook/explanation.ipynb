# %% [markdown]
# # 43_count_array_element
#
# Audience: junior researcher
#
# - Challenge path: `challenges/medium/43_count_array_element`
# - Source spec: [challenges/medium/43_count_array_element/challenge.html](../challenge.html)
# - Source implementation: [challenges/medium/43_count_array_element/challenge.py](../challenge.py)

# %% [markdown]
# ## Problem Statement
#
# The original challenge HTML is embedded below so the notebook stays close to the repo source.
#
# <p>
#   Write a GPU program that counts the number of elements with the integer value k in an array of 32-bit integers.
#   The program should count the number of elements with k in an array.
#   You are given an input array <code>input</code> of length <code>N</code> and integer <code>k</code>.
# </p>
#
# <h2>Implementation Requirements</h2>
# <ul>
#   <li>Use only native features (external libraries are not permitted)</li>
#   <li>The <code>solve</code> function signature must remain unchanged</li>
#   <li>The final result must be stored in the <code>output</code> variable</li>
# </ul>
#
# <h2>Example 1:</h2>
# <pre>
# Input: [1, 2, 3, 4, 1], k = 1
# Output: 2
# </pre>
#
# <h2>Example 2:</h2>
# <pre>
# Input: [5, 10, 5, 2], k = 11
# Output: 0
# </pre>
#
# <h2>Constraints</h2>
# <ul>
#   <li>1 &le; <code>N</code> &le; 100,000,000</li>
#   <li>1 &le; <code>input[i], k</code> &le; 100,000</li>
#
#   <li>Performance is measured with <code>K</code> = 501,010, <code>N</code> = 100,000,000</li>
# </ul>

# %% [markdown]
# ## Framework Coverage
#
# This notebook collects the currently available solution artifacts for PyTorch, JAX, Triton, and MLX.

# %% [markdown]
# ## Pytorch
#
# No solution file is present yet.

# %% [markdown]
# ## Jax
#
# No solution file is present yet.

# %% [markdown]
# ## Triton
#
# No solution file is present yet.

# %% [markdown]
# ## Mlx
#
# No solution file is present yet.

# %% [markdown]
# ## Verification Notes
#
# Use `python scripts/verify_matrix_solutions.py` for the local matrix-operation verifier.
# GPU-only Triton validation still depends on a remote NVIDIA environment.
